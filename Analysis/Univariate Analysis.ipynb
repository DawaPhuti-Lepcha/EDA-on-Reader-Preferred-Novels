# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import datetime as dt

# %%
cn=pd.read_csv(r"..\Data Sets\cleaned_novel_dataset.csv")

# %%
cn["Publish_Date"]=pd.to_datetime(cn["Publish_Date"])

# %%
#Dataset without duplicate values with respect to Novel_Name, Series_Name, Author_Name
without_duplicates=cn.drop_duplicates(subset=['Novel_Name', 'Series_Name', 'Author_Name'],keep="first")
without_duplicates
# Out:
#                                       Novel_Name     Series_Name  \
# 0     Clifford's War: The Bluegrass Battleground               -
# 1                                 Jurassic Park    Jurassic Park
# 2                                      Sunburst   Sky King Ranch
# 3                            The Paris Apartment               -
# 4                                       Dempsey         Tier One
# ...                                          ...             ...
# 6983                                 They Thirst               -
# 6984                                        Snap               -
# 6985                  The Traveling Vampire Show               -
# 6986     WISHBONE...Be Careful What You Wish For               -
# 6987                            Dropcloth Angels               -
#
#               Author_Name              Genre  Average_Rating  No_of_Ratings  \
# 0        J. Denison Reed    Action-Adventure            4.42             33
# ...

# %%
cn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6988 entries, 0 to 6987
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Novel_Name      6988 non-null   object
#  1   Series_Name     6988 non-null   object
#  2   Author_Name     6988 non-null   object
#  3   Genre           6988 non-null   object
#  4   Average_Rating  6988 non-null   float64
#  5   No_of_Ratings   6988 non-null   int64
#  6   No_of_Reviews   6988 non-null   int64
#  7   No_of_Votes     6988 non-null   int64
#  8   Publish_Date    6988 non-null   datetime64[ns]
#  9   Publish_year    6988 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 546.1+ KB

# %%
without_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5711 entries, 0 to 6987
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Novel_Name      5711 non-null   object
#  1   Series_Name     5711 non-null   object
#  2   Author_Name     5711 non-null   object
#  3   Genre           5711 non-null   object
#  4   Average_Rating  5711 non-null   float64
#  5   No_of_Ratings   5711 non-null   int64
#  6   No_of_Reviews   5711 non-null   int64
#  7   No_of_Votes     5711 non-null   int64
#  8   Publish_Date    5711 non-null   datetime64[ns]
#  9   Publish_year    5711 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 490.8+ KB

# %% [markdown]
# ### Univariate Analysis

# %%
# It gives the top 30 novels which are repeated the most in the dataset
pd.DataFrame(cn["Novel_Name"].value_counts().head(30))
# Out:
#                                   Novel_Name
# The Hunger Games                           6
# Mockingjay                                 5
# The Shining                                5
# The Stand                                  5
# A Clockwork Orange                         5
# Dr. Jekyll and Mr. Hyde                    5
# Perfume: The Story of a Murderer           5
# Open Season                                5
# Divergent                                  5
# Naked in Death                             5
# Catching Fire                              5
# The Historian                              5
# One for the Money                          5
# Relic                                      5
# Lord of the Flies                          5
# 11/22/63                                   5
# A Scanner Darkly                           4
# The Road                                   4
# The Drowned World                          4
# Misery                                     4
# ...

# %%
# It gives the top 30 Series which are repeated the most in the dataset
pd.DataFrame(cn["Series_Name"].value_counts().head(30))
# Out:
#                              Series_Name
# -                                   2865
# Jack Reacher                          28
# Hercule Poirot                        26
# Mitch Rapp                            22
# The Dresden Files                     21
# The Dark Tower                        19
# Dirk Pitt                             18
# Anita Blake, Vampire Hunter           18
# Harry Potter                          17
# Immortals After Dark                  17
# Jack Ryan                             16
# Psy-Changeling                        16
# The Hunger Games                      16
# The Mortal Instruments                15
# Sigma Force                           15
# Sherlock Holmes                       15
# Vorkosigan Saga                       15
# The Wheel of Time                     14
# Black Dagger Brotherhood              13
# Newford                               12
# The Hollows                           12
# Hannibal Lecter                       12
# ...

# %%
# It gives the top 30 Series which are repeated the most in the dataset (without duplicate novels)
pd.DataFrame(without_duplicates["Series_Name"].value_counts().head(30))
# Out:
#                              Series_Name
# -                                   2292
# Hercule Poirot                        22
# The Dresden Files                     16
# Jack Reacher                          15
# Anita Blake, Vampire Hunter           15
# Dirk Pitt                             15
# Mitch Rapp                            15
# Vorkosigan Saga                       15
# The Wheel of Time                     14
# Fear Street                           12
# Newford                               12
# Immortals After Dark                  11
# The Hollows                           11
# Black Dagger Brotherhood              11
# Sigma Force                           10
# Psy-Changeling                        10
# Lucas Davenport                       10
# Culture                               10
# Dark                                  10
# The Drenai Saga                        9
# Sherlock Holmes                        9
# Dark-Hunter                            9
# ...

# %%
## It gives the top 30 Authors who are repeated the most in the dataset
pd.DataFrame(cn["Author_Name"].value_counts().head(30))
# Out:
#                       Author_Name
# Stephen King                  112
# Agatha Christie                53
# Dean Koontz                    39
# Nora Roberts                   37
# Lee Child                      34
# James Patterson                29
# Michael Crichton               29
# Tom Clancy                     27
# Isaac Asimov                   26
# Laurell K. Hamilton            25
# Ken Follett                    25
# James Rollins                  25
# Chuck Palahniuk                24
# Neil Gaiman                    24
# Michael Connelly               24
# Jim Butcher                    23
# John Grisham                   23
# Sarah J. Maas                  23
# Vince Flynn                    22
# Brandon Sanderson              22
# Philip K. Dick                 22
# Bret Easton Ellis              22
# Nalini Singh                   22
# Robert A. Heinlein             22
# Richelle Mead                  21
# Kresley Cole                   21
# ...

# %%
# It gives the count of the novel of each genre in the dataset
pd.DataFrame(cn["Genre"].value_counts())
# Out:
#                    Genre
# Crime/Mystery        800
# Urban Fantasy        799
# Science Fiction      796
# Horror/Paranormal    794
# Action-Adventure     793
# Romance              791
# Epic Fantasy         787
# Historical           735
# Suspence/Thriller    693

# %%
# Creating barplot for the count of each Genre
plt.figure(figsize=(8,4))
ax=sns.countplot(x="Genre",data=cn,palette=sns.color_palette("Spectral",9))
plt.title("Count of each Genre")
plt.ylim([0,900])
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',(p.get_x()+p.get_width()/2,p.get_height()+15),ha="center")
plt.show()

# %% [markdown]
# From the above bar plot, we can analyze the distribution of the genre in our dataset. It can be seen that all the data are almost evenly distributed between 787 and 800, apart from "Historical" and "Suspence/Thriller" which has 735 and 693 datas resp.

# %%
cn["Average_Rating"].describe()
# Out:
# count    6988.000000
# mean        4.035541
# std         0.265739
# min         2.000000
# 25%         3.870000
# 50%         4.040000
# 75%         4.200000
# max         5.000000
# Name: Average_Rating, dtype: float64

# %%
cn["No_of_Ratings"].describe()
# Out:
# count    6.988000e+03
# mean     1.672864e+05
# std      5.619514e+05
# min      2.000000e+00
# 25%      4.762500e+03
# 50%      2.503100e+04
# 75%      9.139725e+04
# max      9.802356e+06
# Name: No_of_Ratings, dtype: float64

# %%
cn["No_of_Reviews"].describe()
# Out:
# count      6988.000000
# mean       7296.089725
# std       18468.119189
# min           0.000000
# 25%         274.000000
# 50%        1318.500000
# 75%        5040.000000
# max      237063.000000
# Name: No_of_Reviews, dtype: float64

# %%
cn["Publish_Date"].describe()
# Out:
# C:\Users\dawap\AppData\Local\Temp\ipykernel_27904\284683983.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cn["Publish_Date"].describe()
# count                    6988
# unique                   2987
# top       2009-01-01 00:00:00
# freq                       57
# first     1719-04-25 00:00:00
# last      2023-12-10 00:00:00
# Name: Publish_Date, dtype: object

# %%
# It gives the details of the novel which is the oldest in the dataset
without_duplicates[without_duplicates["Publish_Date"]==without_duplicates["Publish_Date"].min()]
# Out:
#           Novel_Name Series_Name   Author_Name             Genre  \
# 493  Robinson Crusoe           -  Daniel Defoe  Action-Adventure
#
#      Average_Rating  No_of_Ratings  No_of_Reviews  No_of_Votes Publish_Date  \
# 493            3.68         300536           9373           23   1719-04-25
#
#      Publish_year
# 493          1719

# %%
# It gives the details of the most recent novel in the dataset
without_duplicates[without_duplicates["Publish_Date"]==without_duplicates["Publish_Date"].max()]
# Out:
#              Novel_Name Series_Name      Author_Name         Genre  \
# 1423  The Darkest Core    Netherdei  Peter Hackshaw   Epic Fantasy
#
#       Average_Rating  No_of_Ratings  No_of_Reviews  No_of_Votes Publish_Date  \
# 1423            4.14            258             10           13   2023-12-10
#
#       Publish_year
# 1423          2023

# %%
#It gives the top 20 years in which there are more number of novels published in the dataset
pd.DataFrame(without_duplicates["Publish_year"].value_counts().head(20))
# Out:
#       Publish_year
# 2011           330
# 2012           322
# 2013           252
# 2009           243
# 2010           243
# 2014           224
# 2008           181
# 2015           170
# 2007           164
# 2006           163
# 2016           143
# 2017           137
# 2005           128
# 2004           124
# 2003           111
# 2018            99
# 2023            99
# 2001            96
# 2002            96
# 2019            92

# %%
# Plotting histogram of Publish Year
plt.figure(figsize=(8,4))
ax=sns.histplot(x=without_duplicates["Publish_year"],binwidth=10,stat="count",kde=True,palette="flare")
plt.title("Histogram of Publish Year")
plt.ylim([0,2500])
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',(p.get_x()+p.get_width()/2,p.get_height()+15),ha="center")
plt.show()
# Out:
# C:\Users\dawap\AppData\Local\Temp\ipykernel_27904\798633313.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.histplot(x=without_duplicates["Publish_year"],binwidth=10,stat="count",kde=True,palette="flare")

# %%
#Plotting KDE of Publish Year with mean, median and mode
plt.figure(figsize=(8,4))
sns.kdeplot(without_duplicates["Publish_year"])
plt.title("Kernel Density Estimate of Publish Year")
plt.axvline(without_duplicates["Publish_year"].mean(),color="green",label="Mean")
plt.axvline(without_duplicates["Publish_year"].median(),color="red",label="Median")
plt.axvline(without_duplicates["Publish_year"].mode()[0],color="purple",label="Mode")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# From the above kde plot, it can be observed that most of the novels in the dataset are published after 1980.

# %%
without_duplicates["Publish_year"].mean()
# Out:
# 1997.8273507266679

# %%
without_duplicates["Publish_year"].median()
# Out:
# 2007.0

# %%
without_duplicates["Publish_year"].mode()[0]
# Out:
# 2011

# %%
# Plottting Histogram of Average Rating 
plt.figure(figsize=(8,4))
ax=sns.histplot(without_duplicates["Average_Rating"],binwidth=0.25,stat="count",kde=True,palette="flare")
plt.title("Histogram of Average rating")
plt.ylim([0,3000])
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',(p.get_x()+p.get_width()/2,p.get_height()+15),ha="center")
plt.show()
# Out:
# C:\Users\dawap\AppData\Local\Temp\ipykernel_27904\2974144071.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.histplot(without_duplicates["Average_Rating"],binwidth=0.25,stat="count",kde=True,palette="flare")

# %% [markdown]
# From the above kde plot, it can be observed that the most number of ratings for the novels in the dataset are between 3.75 and 4.30

# %%
without_duplicates["Average_Rating"].mean()
# Out:
# 4.030987567851515

# %%
without_duplicates["Average_Rating"].median()
# Out:
# 4.04

# %%
without_duplicates["Average_Rating"].mode()[0]
# Out:
# 4.08
